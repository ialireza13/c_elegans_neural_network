# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import pandas as pd
import utils.functions as functions
from utils.functions import *
import importlib
import json
from utils.graph_repair import repair_network
import matplotlib.patches as patches
import itertools

# %load_ext autoreload
# %autoreload 2

cmap = get_colormap()
# Out:
# Please install pyparsing, pydot & graphviz if you want to draw graphs or lattice diagrams

# %%
input_file = 'dataset/worms'


worm_dicts = read_input_mat_file(input_file, remove_trend=True, smooth_spikes=True, mean_zero=True, meanmax_thresh=None)

averaged_results = calculate_metrics(worm_dicts, use_annotations = True, return_average = True)
# Out:
# 100%|██████████| 8/8 [00:56<00:00,  7.09s/it]

# %%
fig, ax = plt.subplots(2, 4, figsize=(15, 5))
ax = ax.flatten()

for i, worm_dict in enumerate(worm_dicts):
    for key, value in worm_dict.items():
        if key == 'annot':
            for idx in range(len(value)):
                if value[idx] > 1:
                    ax[i].axvspan(idx, idx, color='tab:red', alpha=0.03)
        else:
            ax[i].plot(value)
    ax[i].set_title(f'Worm {i+1}')
    
plt.tight_layout()

# %%
pairs = list(set(averaged_results.keys()))

## all neurons including AVAR, AVAL, etc
# all_neurons = list(set([item for sublist in pairs for item in sublist]))
# all_neurons.sort()

## to replicate the results in the paper
# all_neurons = ['VA05', 'VA06', 'VA07', 'DA07', 'DA08', 'VA04', 'DA09', 'DA02', 'VA02', 'DA03', 'VA01', 'DA01', 'DA06', 'DA04', 'VA08', 'DA05', 'VA11', 'VA09', 'VA10', 'VA03', 'VA12']
all_neurons = ['DA02', 'VA02', 'VA03', 'DA03', 'DA01', 'DA08', 'DA09', 'VA12', 'VA07', 'VA05', 'VA04', 'VA06', 'DA07', 'VA01', 'VA09', 'VA10', 'VA11', 'DA05', 'DA04', 'VA08', 'DA06']
# all_neurons = ['VA04', 'VA05', 'VA06', 'VA02', 'DA08', 'VA07', 'DA02', 'DA09', 'VA03', 'VA11', 'VA12', 'VA08', 'VA09', 'VA10', 'DA03', 'DA04', 'DA07', 'DA01', 'DA05', 'VA01', 'DA06']

mapping_neuron_to_idx = {all_neurons[idx]:idx for idx in range(len(all_neurons))}
mapping_idx_to_neuron = {idx:all_neurons[idx] for idx in range(len(all_neurons))}

# %%
matrices = {}
modified_matrices = {}

for metric in averaged_results[pairs[0]]:
    matrix = np.ones((len(mapping_neuron_to_idx), len(mapping_neuron_to_idx)))
    for pair in pairs:
        if pair[0] in mapping_neuron_to_idx and pair[1] in mapping_neuron_to_idx:
            matrix[mapping_neuron_to_idx[pair[0]], mapping_neuron_to_idx[pair[1]]] = averaged_results[pair][metric]
            matrix[mapping_neuron_to_idx[pair[1]], mapping_neuron_to_idx[pair[0]]] = averaged_results[pair][metric]
    
    threshold = calculate_percolation(matrix)
    modified_matrix = np.where(matrix >= threshold, matrix, 0)
    
    matrices[metric] = matrix
    modified_matrices[metric] = modified_matrix

# %%
plt.rcParams.update({'font.size': 11})

metric = 'los_0.16'
# metric = 'pearson'
# plt.imshow(np.where(matrices[metric]>0.64, matrices[metric], 0), cmap=cmap, vmin=0, vmax=1)
plt.imshow(matrices[metric], cmap=cmap, vmin=0, vmax=1)
# plt.imshow(matrices[metric], cmap=cmap, vmin=0, vmax=1)
plt.xticks(range(len(all_neurons)), all_neurons, rotation=90)
plt.yticks(range(len(all_neurons)), all_neurons)
plt.title(metric)
plt.colorbar();

# %%
plt.rcParams.update({'font.size': 13})

# Create figure and axes
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(6, 10), constrained_layout=True)

# Plot heatmaps using imshow
im1 = axes[0].imshow(matrices[metric], cmap=cmap, aspect='auto', vmin=0, vmax=1)
im2 = axes[1].imshow(modified_matrices[metric], cmap=cmap, aspect='auto', vmin=0, vmax=1)
axes[0].set_xticks(range(len(all_neurons)), all_neurons, rotation=90)
axes[0].set_yticks(range(len(all_neurons)), all_neurons)
axes[1].set_xticks(range(len(all_neurons)), all_neurons, rotation=90)
axes[1].set_yticks(range(len(all_neurons)), all_neurons)
# Only show x-ticks on the top plot
axes[0].tick_params(bottom=True, labelbottom=True)  # Hide x-axis labels and ticks
axes[1].tick_params(top=False, bottom=False, labelbottom=False)  # Ensure no top ticks in the bottom plot

# Share the colorbar for both heatmaps
cbar = fig.colorbar(im1, ax=axes, orientation='vertical', shrink=0.5, pad=0.02)

# Show the plot
fig.savefig('plots/AB.svg')

# %%
datatable = [['louvain', 'covariance', 'cov'], ['louvain', 'los_0.060000000000000005', 'los_06'],
             ['clique', 'covariance', 'cov'], ['clique', 'los_0.16', 'los_16'], ['clique', 'los_0.17', 'los_17']]

for method, metric, name in tqdm(datatable):
    all_cliques = []

    if method == 'louvain':
        louvain_results = louvain_clustering_best_modularity(modified_matrices[metric], all_neurons, 1000)
        clusters = louvain_results
    if method == 'clique':
        valid_cliques = check_cliques_struc_v2(modified_matrices[metric], all_neurons, 2, 9)
        refined_cliques = refine_cliques(valid_cliques)
        clusters = refined_cliques

    with open(f'colorings/{method[:4]}_{name}_colors_collapsed.txt', 'w') as f:
        for idx, clique in enumerate(clusters):
            for node in clique:
                print(f'{node}\t{idx}', file=f)
                
        print(f'AVE\t{idx+1}', file=f)
        
        print(f'AVD\t{idx+2}', file=f)
        
        print(f'AVA\t{idx+3}', file=f)
        
    with open(f'colorings/{method[:4]}_{name}_colors_uncollapsed.txt', 'w') as f:
        for idx, clique in enumerate(clusters):
            for node in clique:
                print(f'{node}\t{idx}', file=f)
            
        print(f'AVEL\t{idx+1}', file=f)
        print(f'AVER\t{idx+1}', file=f)
        
        print(f'AVDL\t{idx+2}', file=f)
        print(f'AVDR\t{idx+2}', file=f)
        
        print(f'AVAL\t{idx+3}', file=f)
        print(f'AVAR\t{idx+3}', file=f)
# Out:
# 100%|██████████| 5/5 [04:27<00:00, 53.48s/it]

# %%
collapsed = 'collapsed'
df_weights = pd.read_csv(f'connectomes/{collapsed}_varshney_weights.txt', sep='\t', header=None)
n_shuffle = 1000

res = {}

for run in tqdm(datatable):
    df = pd.read_csv(f"colorings/{run[0][:4]}_{run[2]}_colors_{collapsed}.txt", sep='\t', header=None)
    n_colors = str(df[~df[0].str.startswith('A')][1].max()+1)
    res[run[0]+ '-' + run[2] + '-' + n_colors] = {}
    for a in [1,2]:
        for b in [1,2]:
            
            shuffled_results = []
            for n in range(n_shuffle):
                shuffled_values = np.random.permutation(df.loc[~df[0].str.startswith('A'), 1].values)
                df_copy = df.copy()
                df_copy.loc[~df_copy[0].str.startswith('A'), 1] = shuffled_values
                df_copy.to_csv(f"colorings/temp_shuffle.txt", sep='\t', header=None, index=None)
                EdgesRemoved, EdgesAdded, G_result = repair_network(f"colorings/temp_shuffle.txt", f"connectomes/{collapsed}_varshney.graph.txt", f"outputs/{collapsed}_{run[0][:4]}_{run[2]}_colors_o_", a, b, prohibit_file_path=f"connectomes/{collapsed}_prohibited_edges.txt")
                shuffled_results.append(1.0*(sum([df_weights[(df_weights[0] == edge[0]) & (df_weights[1] == edge[1])][2].values[0] for edge in EdgesRemoved]) + len(EdgesAdded)) / df_weights[2].sum())
            
            EdgesRemoved, EdgesAdded, G_result = repair_network(f"colorings/{run[0][:4]}_{run[2]}_colors_{collapsed}.txt", f"connectomes/{collapsed}_varshney.graph.txt", f"outputs/{collapsed}_{run[0][:4]}_{run[2]}_colors_o_", a, b, prohibit_file_path=f"connectomes/{collapsed}_prohibited_edges.txt")
            # res[run[0]+ '-' + run[2]][(a,b)] = [(len(EdgesRemoved)+len(EdgesAdded))/56.0]
            res[run[0]+ '-' + run[2] + '-' + n_colors][(a,b)] = ((sum([df_weights[(df_weights[0] == edge[0]) & (df_weights[1] == edge[1])][2].values[0] for edge in EdgesRemoved]) + len(EdgesAdded)) / df_weights[2].sum(), 
                                                                 (np.array(shuffled_results) < (sum([df_weights[(df_weights[0] == edge[0]) & (df_weights[1] == edge[1])][2].values[0] for edge in EdgesRemoved]) + len(EdgesAdded)) / df_weights[2].sum()).sum() / n_shuffle)
            # res[run[0]+ '-' + run[2]][(a,b)] = (sum([df_weights[(df_weights[0] == edge[0]) & (df_weights[1] == edge[1])][2].values[0] for edge in EdgesRemoved]) + len(EdgesAdded)) / df_weights.shape[0]

# %%
import matplotlib.cm as cm

colormap = cm.get_cmap('tab10', 8)

color_dict = {
    1: '223,137,255',
    2: '121,114,255',
    3: '115,192,0',
    4: '255,136,5',
    5: '0,196,255',
    6: '255,85,132',
    7: '0,189,148',
    8: '211,179,176'
}

color_dict = {
    1: (255, 0, 0),      # Red
    2: (0, 255, 0),      # Green
    3: (0, 0, 255),      # Blue
    4: (255, 255, 0),    # Yellow
    5: (255, 165, 0),    # Orange
    6: (128, 0, 128),    # Purple
    7: (0, 255, 255),    # Cyan
    8: (255, 20, 147),   # Deep Pink
    9: (139, 69, 19),    # Saddle Brown
    10: (0, 128, 128)    # Teal
}
# Out:
# /tmp/ipykernel_2202821/4229067047.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colormap = cm.get_cmap('tab10', 8)

# %% [markdown]
# ## Here

# %%
df = pd.read_csv('connectomes/uncollapsed_varshney_weights.txt', sep='\t', header=None)
df.rename(columns={0: 'source', 1: 'target', 2: 'weight'}, inplace=True)

G_orig = nx.from_pandas_edgelist(df, create_using=nx.DiGraph, edge_attr='weight')
G_orig.add_node('VA07')

colors = pd.read_csv('colorings/cons_7_colors_uncollapsed.txt', sep='\t', header=None)

for row in colors.iterrows():
    G_orig.nodes[row[1][0]]['rgb'] = str(color_dict[row[1][1]])[1:-1].replace(' ','')
    G_orig.nodes[row[1][0]]['color'] = row[1][1]

# %%
pfile = "connectomes/collapsed_prohibited_edges.txt"
# pfile = None
EdgesRemoved, EdgesAdded, G_result = repair_network(f"colorings/cons_7_colors_collapsed.txt", "connectomes/collapsed_varshney.graph.txt", f"outputs/collapsed_colors_o_", 1, 1, prohibit_file_path=pfile)

for row in colors.iterrows():
    G_result.nodes[row[1][0]]['rgb'] = str(color_dict[row[1][1]])[1:-1].replace(' ','')
    G_result.nodes[row[1][0]]['color'] = row[1][1]
    
df_weights = pd.read_csv(f'connectomes/collapsed_varshney_weights.txt', sep='\t', header=None)
modification_epsilon(EdgesRemoved, EdgesAdded, df_weights, how='edge_weight_new')
# Out:
# 0.09041095890410959

# %%
from scipy.stats import norm

def one_sided_p_value(mean, std, x):
    z_score = (x - mean) / std
    p_value = norm.cdf(z_score)  # One-sided (upper tail) p-value
    return p_value

# %%
nx.write_gexf(G_orig, 'unc_orig.gexf')
# nx.write_gexf(G_result, 'c_rep.gexf')

# %%
# paper figure positions
# pos = {
#     'AVD': (0,0),
#     'AVE': (1,1),
#     'AVA': (-1,-1),
    
#     'VA04': (3,2),
#     'DA09': (3,1.5),
#     'DA08': (3,1),
#     'DA07': (3,0.5),
#     'VA07': (3,0),
#     'VA05': (3,-0.5),
#     'VA06': (3,-1),
    
#     'VA02': (-1,-2),
#     'DA02': (-0.5,-2),
#     'DA03': (0,-2),
#     'VA01': (0.5,-2),
    
#     'DA01': (1,4),
#     'DA06': (0,4),
#     'VA03': (-1,4),
#     'VA12': (-2,4),
    
#     'VA11': (-2,3),
#     'VA10': (-2,2.5),
#     'DA05': (-2,2),
#     'VA09': (-2,1.5),
#     'VA08': (-2,1),
#     'DA04': (-2,0.5),
# }

# worm body positions
pos = {
    'VA01': (0,0),
    'VA02': (1,0),
    'VA03': (2,0),
    'VA04': (3,0),
    'VA05': (4,0),
    'VA06': (5,0),
    'VA07': (6,0),
    'VA08': (7,0),
    'VA09': (8,0),
    'VA10': (9,0),
    'VA11': (10,0),
    'VA12': (11,0),
    
    'DA01': (0, 1),
    'DA02': (1, 1),
    'DA03': (2, 1),
    'DA04': (3, 1),
    'DA05': (4, 1),
    'DA06': (5, 1),
    'DA07': (6, 1),
    'DA08': (7, 1),
    'DA09': (8, 1),
    
    'AVA': (1, 0.5),
    'AVE': (2, 0.5),
    'AVD': (3, 0.5),
}

if 'AVAL' in G_orig.nodes():
    pos['AVAL'] = (1, 0.7)
    pos['AVAR'] = (1, 0.3)
    
    pos['AVEL'] = (2, 0.7)
    pos['AVER'] = (2, 0.3)
    
    pos['AVDL'] = (3, 0.7)
    pos['AVDR'] = (3, 0.3)

# %%
# # paper's colorings
# G_orig.nodes['VA12']['color'] = 0
# G_orig.nodes['VA03']['color'] = 0

# G_orig.nodes['DA06']['color'] = 1
# G_orig.nodes['DA01']['color'] = 1

# G_orig.nodes['DA08']['color'] = 2
# G_orig.nodes['DA09']['color'] = 2
# G_orig.nodes['VA04']['color'] = 2

# G_orig.nodes['VA02']['color'] = 3
# G_orig.nodes['DA02']['color'] = 3
# G_orig.nodes['DA03']['color'] = 3

# G_orig.nodes['VA11']['color'] = 4
# G_orig.nodes['VA10']['color'] = 4
# G_orig.nodes['DA05']['color'] = 4
# G_orig.nodes['VA09']['color'] = 4
# G_orig.nodes['VA08']['color'] = 4
# G_orig.nodes['DA04']['color'] = 4

# G_orig.nodes['AVD']['color'] = 5

# G_orig.nodes['AVE']['color'] = 6

# G_orig.nodes['AVA']['color'] = 7

# G_orig.nodes['DA07']['color'] = 8
# G_orig.nodes['VA07']['color'] = 8
# G_orig.nodes['VA05']['color'] = 8
# G_orig.nodes['VA06']['color'] = 8

# G_orig.nodes['VA01']['color'] = 9

# %%
plot_graph_with_weights_and_groups(G_orig, pos=pos, draw_edge_labels=False, uniform_edges=True)

# %%
plot_graph_with_weights_and_groups(G_result, pos=pos, draw_edge_labels=False, uniform_edges=True)

# %%
print(EdgesAdded)
print(EdgesRemoved)
# Out:
# [('VA03', 'DA05'), ('VA12', 'VA10'), ('VA04', 'DA04'), ('VA04', 'DA06'), ('AVE', 'VA07'), ('AVE', 'VA06'), ('AVD', 'VA12'), ('AVD', 'VA04'), ('AVD', 'DA06'), ('AVD', 'VA08'), ('AVD', 'VA07'), ('VA01', 'AVE'), ('AVA', 'VA07'), ('AVA', 'VA01')]
# [('AVD', 'DA01'), ('AVD', 'VA11'), ('AVE', 'VA03'), ('AVE', 'DA01'), ('AVE', 'DA04'), ('AVE', 'VA01'), ('AVE', 'VA04'), ('DA03', 'DA04'), ('DA04', 'DA03'), ('VA12', 'DA09'), ('VA02', 'VA03'), ('VA03', 'VA04')]

# %%
plot_graph_with_weights_and_groups(G_result, pos=pos, draw_edge_labels=False, uniform_edges=True)

# %%
print(EdgesAdded)
print(EdgesRemoved)
# Out:
# [('AVE', 'DA07'), ('AVE', 'VA07'), ('AVE', 'VA06'), ('DA06', 'AVE'), ('DA09', 'VA10'), ('AVD', 'DA06'), ('AVD', 'VA07'), ('AVA', 'VA07'), ('AVA', 'VA01')]
# [('AVA', 'AVE'), ('AVD', 'DA01'), ('AVD', 'DA09'), ('AVD', 'VA03'), ('AVD', 'VA11'), ('AVE', 'VA03'), ('AVE', 'DA04'), ('AVE', 'VA04'), ('DA03', 'DA04'), ('DA04', 'DA03'), ('VA12', 'DA08'), ('VA12', 'DA09'), ('VA02', 'VA03'), ('VA03', 'VA04')]

# %%
try:
    with open('precomputed/all_cliques_detrend_demean_despike.json', 'r') as file:
        # Load the JSON data from the file
        all_cliques = json.load(file)
except:
    all_cliques = []

    for metric, matrix in tqdm(modified_matrices.items(), total=len(modified_matrices)):
        valid_cliques = check_cliques_struc_v2(matrix, all_neurons, 2, 9)
        refined_cliques = refine_cliques(valid_cliques)
        louvain_results = louvain_clustering_best_modularity(matrix, all_neurons, 100)
        
        all_cliques.append(refined_cliques)
        all_cliques.append(louvain_results)
        
    # Convert the list to a JSON string
    json_string = json.dumps(all_cliques)

    # Save the JSON string to a file
    with open("precomputed/all_cliques_detrend_demean_despike.json", "w") as f:
        f.write(json_string)

# %%
def create_point_cluster_mapping(clustering_results, columns):
    points = set()
    metric_cluster_mapping = []

    # Collect unique points and map their clusters
    for metric in clustering_results:
        metric_map = {}
        for cluster_id, cluster_points in enumerate(metric):
            for point in cluster_points:
                metric_map[point] = cluster_id
                points.add(point)
        metric_cluster_mapping.append(metric_map)

    # Convert to DataFrame
    points = sorted(points)  # Ensure consistent ordering
    data = []
    for metric_map in metric_cluster_mapping:
        data.append([metric_map.get(point, -1) for point in points])  # -1 if point is not in metric

    return pd.DataFrame(data, index=columns, columns=points).T

# %%
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, jaccard_score

metric_names = [[x[:10]+'_c', x[:10]+'_l'] for x in list(modified_matrices.keys())]
metric_names = sum(metric_names, [])

df = create_point_cluster_mapping(list(all_cliques.values()), metric_names)
res = np.zeros((len(df.columns), len(df.columns)))

for col1 in enumerate(df.columns):
    for col2 in enumerate(df.columns):
        # res[col1[0], col2[0]] = adjusted_rand_score(df[col1[1]], df[col2[1]])
        res[col1[0], col2[0]] = normalized_mutual_info_score(df[col1[1]], df[col2[1]])
        # res_clique[col1[0], col2[0]] = normalized_mutual_info_score(df_clusters_cliq[col1[1]], df_clusters_cliq[col2[1]]
        # res[col1[0], col2[0]] = jaccard_score(df[col1[1]], df[col2[1]], average='macro')

# %%
plt.figure(figsize=(7, 7))
# plt.imshow(res[::2, ::2], cmap='viridis')
# plt.title('Clique')
plt.imshow(res[1::2, 1::2], cmap='viridis')
plt.title('Louvain')

plt.xticks(range(44), [x[:-2] for x in metric_names[1::2]], rotation=90)
plt.yticks(range(44), [x[:-2] for x in metric_names[1::2]])
plt.colorbar()

plt.tight_layout()

# %%
def get_thresholds_for_clusters(linkage_matrix):
    """
    Given a SciPy linkage matrix, compute the threshold values that lead to different cluster counts.
    
    Parameters:
        linkage_matrix (ndarray): The linkage matrix from scipy's hierarchical clustering.

    Returns:
        dict: A mapping from number of clusters to the corresponding threshold.
    """
    num_points = linkage_matrix.shape[0] + 1  # Initial clusters = number of original points
    thresholds = {num_points: 0}  # Start with N clusters (threshold = 0)
    
    for i, row in enumerate(linkage_matrix):
        cluster_count = num_points - (i + 1)  # Number of clusters at this step
        threshold = row[2]  # The merge distance at this step
        thresholds[cluster_count] = threshold
    
    return thresholds

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
plt.rcParams.update({'font.size': 18})
temp =  ['VA05', 'VA06', 'VA07', 'DA07', 'DA08', 'VA04', 'DA09', 'DA02', 'VA02', 'DA03', 'VA01', 'DA01', 'DA06', 'DA04', 'VA08', 'DA05', 'VA11', 'VA09', 'VA10', 'VA03', 'VA12']
mapping = {x:mapping_neuron_to_idx[x] for x in temp}
mapping = mapping_neuron_to_idx
cooccurrence_matrix = get_cooccurrence_matrix(list(all_cliques.values()), mapping)

# Step 4: Perform Hierarchical Clustering using Ward's Method
linkage_matrix = linkage(cooccurrence_matrix, method='ward')

# Step 5: Plot the Dendrogram
plt.figure(figsize=(8, 6))
with plt.rc_context({'lines.linewidth': 4}):
    dendo = dendrogram(linkage_matrix, labels=all_neurons, color_threshold=3)

cooccurrence_matrix = cooccurrence_matrix[np.ix_(dendo['leaves'], dendo['leaves'])]

new_node_order = [all_neurons[node] for node in dendo['leaves']]
# new_node_order = temp

# plt.title("Hierarchical Clustering Dendrogram")
# plt.xlabel("Nodes")
plt.xticks([])
plt.tight_layout()
# plt.ylabel("Distance")
plt.savefig('plots/dendrogram.svg')

# %%
thresh = get_thresholds_for_clusters(linkage_matrix)
thresh
# Out:
# {21: 0,
#  20: 0.0514896145500656,
#  19: 0.09128133038916808,
#  18: 0.09795278524810502,
#  17: 0.19729688675754192,
#  16: 0.2557259927357538,
#  15: 0.3010732810556014,
#  14: 0.30955005199900926,
#  13: 0.3970920684735346,
#  12: 0.4676101583524677,
#  11: 0.5424767507673398,
#  10: 0.7353329560429743,
#  9: 0.8088326940591094,
#  8: 0.9215880751343134,
#  7: 1.0470740639718352,
#  6: 1.222311484296254,
#  5: 1.4267450947730314,
#  4: 2.304113792650434,
#  3: 2.6970393838224975,
#  2: 3.9419208513053636,
#  1: 6.0774332221909395}

# %%
plt.rcParams.update({'font.size': 12})

plt.imshow(cooccurrence_matrix, cmap=cmap)
plt.xticks(range(len(new_node_order)), new_node_order, rotation=90)
plt.yticks(range(len(new_node_order)), new_node_order)
plt.colorbar(pad=0.02)

squares = [
    [0, 5, 3],
    [6, 13, 3],
    [14, 20, 3],
    
    [0, 5, 2],
    [6, 8, 2],
    [9, 13, 2],
    [14, 14, 2],
    [15, 16, 2],
    [17, 18, 2],
    [19, 20, 2],
]

for start, end, thickness in squares:
    # Add a square (rectangle with equal height and width)
    ax = plt.gca()
    rect = patches.Rectangle(
        (start - 0.5, start - 0.5),  # Rectangle starts slightly offset to align with pixels
        end - start + 1,            # Width
        end - start + 1,            # Height
        linewidth=thickness,                    # Line thickness
        edgecolor='black',                # Line color
        facecolor='none'                # Transparent fill
    )
    ax.add_patch(rect)

plt.tight_layout()
plt.savefig('plots/cooccurrence.svg')

# %%
def remove_duplicates(nested_list):
    seen = set()
    unique_list = []
    
    for sublist in nested_list:
        # Convert inner lists to sorted tuples
        sorted_sublist = tuple(tuple(sorted(inner)) for inner in sublist)
        
        if sorted_sublist not in seen:
            seen.add(sorted_sublist)
            unique_list.append(sublist)
    
    return unique_list

# %%
len(remove_duplicates([v for k, v in all_cliques.items() if k[0]!='l' and k[-1]=='n']))
# Out:
# 4

# %%
from collections import Counter
plt.rcParams.update({'font.size': 12})

plt.figure(figsize=(7,4))

size_dist = [len(x) for x in remove_duplicates([v for k, v in all_cliques.items() if k[0]=='l'])]
count_dict = Counter(size_dist)

plt.bar(x=[x-0.2 for x in count_dict.keys()], height=count_dict.values(), width=0.4, label='LoS', color='tab:orange')

size_dist = [len(x) for x in remove_duplicates([v for k, v in all_cliques.items() if k[0]!='l'])]
count_dict = Counter(size_dist)

plt.bar(x=[x+0.2 for x in count_dict.keys()], height=count_dict.values(), width=0.4, label='Corr', color='tab:blue')

plt.grid(True, 'major', 'y')
plt.xlim([1.5,4.5])

plt.xticks([2,3,4])
plt.yticks([0,5,10,15,20])
plt.xlabel('Number of Colors')
plt.ylabel('Count')
plt.legend()

# %%
for n_cluster in [3,4,5,6,7,8,9,10]:
    clusters = fcluster(linkage_matrix, n_cluster, criterion='maxclust')
    
    with open(f'colorings/cons_{n_cluster}_colors_collapsed.txt', 'w') as f:
        max_id = np.max(clusters)
        for idx, neuron in enumerate(all_neurons):
            print(f'{neuron}\t{clusters[idx]}', file=f)
            
        print(f'AVE\t{max_id+1}', file=f)
        
        print(f'AVD\t{max_id+2}', file=f)
        
        print(f'AVA\t{max_id+3}', file=f)

# %%
collapsed = 'collapsed'
df_weights = pd.read_csv(f'connectomes/{collapsed}_varshney_weights.txt', sep='\t', header=None)

res = {}

for idx, i in enumerate([3,4,5,6,7,8,9,10]):
    res[i] = {}
    for a in [1,2]:
        for b in [1,2]:
            EdgesRemoved,EdgesAdded, G_result = repair_network(f"colorings/cons_{i}_colors_collapsed.txt", "connectomes/collapsed_varshney.graph.txt", f"outputs/collapsed_cons_{i}_colors_o_", a, b, prohibit_file_path="connectomes/collapsed_prohibited_edges.txt")
            res[i][(a,b)] = (sum([df_weights[(df_weights[0] == edge[0]) & (df_weights[1] == edge[1])][2].values[0] for edge in EdgesRemoved]) + len(EdgesAdded)) / df_weights[2].sum()
# Out:
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.13201189041137695
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 4776 rows, 3649 columns and 33870 nonzeros
# Model fingerprint: 0x46848163
# Model has 212 simple general constraints
#   212 ABS
# Variable types: 129 continuous, 3096 integer (3096 binary)
# Semi-Variable types: 0 continuous, 424 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3048 rows and 2343 columns
# Presolve time: 0.05s
# Presolved: 1728 rows, 1306 columns, 6486 nonzeros
# Variable types: 0 continuous, 1306 integer (892 binary)
# Found heuristic solution: objective 191.0000000
# Found heuristic solution: objective 45.0000000
#
# Root relaxation: objective 2.400000e+01, 120 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   24.00000    0    2   45.00000   24.00000  46.7%     -    0s
# H    0     0                      28.0000000   24.00000  14.3%     -    0s
# H    0     0                      27.0000000   24.00000  11.1%     -    0s
# H    0     0                      26.0000000   24.00000  7.69%     -    0s
#
# Cutting planes:
#   Clique: 1
#   Zero half: 2
#
# Explored 1 nodes (302 simplex iterations) in 0.12 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 26 27 28 ... 191
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.600000000000e+01, best bound 2.400000000000e+01, gap 7.6923%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.11610984802246094
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 4776 rows, 3649 columns and 33870 nonzeros
# Model fingerprint: 0xcf3e291f
# Model has 212 simple general constraints
#   212 ABS
# Variable types: 129 continuous, 3096 integer (3096 binary)
# Semi-Variable types: 0 continuous, 424 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3048 rows and 2343 columns
# Presolve time: 0.05s
# Presolved: 1728 rows, 1306 columns, 6486 nonzeros
# Variable types: 0 continuous, 1306 integer (892 binary)
# Found heuristic solution: objective 372.0000000
# Found heuristic solution: objective 83.0000000
#
# Root relaxation: objective 3.000000e+01, 157 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   30.00000    0   82   83.00000   30.00000  63.9%     -    0s
# H    0     0                      50.0000000   30.00000  40.0%     -    0s
#      0     0   30.00000    0  144   50.00000   30.00000  40.0%     -    0s
#      0     0   30.00000    0  138   50.00000   30.00000  40.0%     -    0s
# H    0     0                      44.0000000   30.00000  31.8%     -    0s
# H    0     0                      42.0000000   30.00000  28.6%     -    0s
# H    0     0                      40.0000000   30.00000  25.0%     -    0s
#      0     0   30.00000    0  134   40.00000   30.00000  25.0%     -    0s
#      0     0   30.00000    0  105   40.00000   30.00000  25.0%     -    0s
#      0     0   30.00000    0   95   40.00000   30.00000  25.0%     -    0s
#      0     0   32.00000    0    5   40.00000   32.00000  20.0%     -    0s
# H    0     0                      36.0000000   32.00000  11.1%     -    0s
# H    0     0                      34.0000000   32.00000  5.88%     -    0s
#      0     0   32.00000    0    5   34.00000   32.00000  5.88%     -    0s
#
# Explored 1 nodes (763 simplex iterations) in 0.16 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 34 36 40 ... 372
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.400000000000e+01, best bound 3.400000000000e+01, gap 0.0000%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.115509033203125
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 4776 rows, 3649 columns and 33870 nonzeros
# Model fingerprint: 0xf95d8645
# Model has 212 simple general constraints
#   212 ABS
# Variable types: 129 continuous, 3096 integer (3096 binary)
# Semi-Variable types: 0 continuous, 424 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3048 rows and 2343 columns
# Presolve time: 0.05s
# Presolved: 1728 rows, 1306 columns, 6486 nonzeros
# Variable types: 0 continuous, 1306 integer (892 binary)
# Found heuristic solution: objective 210.0000000
# Found heuristic solution: objective 49.0000000
#
# Root relaxation: objective 3.300000e+01, 301 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   33.00000    0   26   49.00000   33.00000  32.7%     -    0s
# H    0     0                      46.0000000   33.00000  28.3%     -    0s
# H    0     0                      44.0000000   33.00000  25.0%     -    0s
#      0     0   33.00000    0   34   44.00000   33.00000  25.0%     -    0s
#      0     0   33.00000    0   22   44.00000   33.00000  25.0%     -    0s
#      0     0   33.00000    0  131   44.00000   33.00000  25.0%     -    0s
#      0     0   33.00000    0    5   44.00000   33.00000  25.0%     -    0s
# H    0     0                      39.0000000   33.00000  15.4%     -    0s
# H    0     0                      35.0000000   33.00000  5.71%     -    0s
#
# Explored 1 nodes (1052 simplex iterations) in 0.16 seconds (0.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 35 39 44 ... 210
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.500000000000e+01, best bound 3.300000000000e+01, gap 5.7143%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.11773300170898438
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 4776 rows, 3649 columns and 33870 nonzeros
# Model fingerprint: 0x893b386d
# Model has 212 simple general constraints
#   212 ABS
# Variable types: 129 continuous, 3096 integer (3096 binary)
# Semi-Variable types: 0 continuous, 424 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3048 rows and 2343 columns
# Presolve time: 0.07s
# Presolved: 1728 rows, 1306 columns, 6486 nonzeros
# Variable types: 0 continuous, 1306 integer (892 binary)
# Found heuristic solution: objective 382.0000000
# Found heuristic solution: objective 90.0000000
#
# Root relaxation: objective 4.800000e+01, 120 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   48.00000    0    2   90.00000   48.00000  46.7%     -    0s
# H    0     0                      56.0000000   48.00000  14.3%     -    0s
# H    0     0                      54.0000000   48.00000  11.1%     -    0s
# H    0     0                      52.0000000   48.00000  7.69%     -    0s
#
# Cutting planes:
#   Clique: 1
#   Zero half: 2
#
# Explored 1 nodes (302 simplex iterations) in 0.11 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 52 54 56 ... 382
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.200000000000e+01, best bound 4.800000000000e+01, gap 7.6923%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.13543319702148438
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 5644 rows, 4241 columns and 36766 nonzeros
# Model fingerprint: 0x3b250a54
# Model has 224 simple general constraints
#   224 ABS
# Variable types: 105 continuous, 3688 integer (3688 binary)
# Semi-Variable types: 0 continuous, 448 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3151 rows and 2381 columns
# Presolve time: 0.06s
# Presolved: 2493 rows, 1860 columns, 9418 nonzeros
# Variable types: 0 continuous, 1860 integer (1350 binary)
# Found heuristic solution: objective 38.0000000
#
# Root relaxation: objective 2.200000e+01, 145 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   22.00000    0    6   38.00000   22.00000  42.1%     -    0s
# H    0     0                      29.0000000   22.00000  24.1%     -    0s
# H    0     0                      28.0000000   22.00000  21.4%     -    0s
# H    0     0                      23.0000000   22.00000  4.35%     -    0s
#
# Explored 1 nodes (340 simplex iterations) in 0.10 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 23 28 29 38
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.300000000000e+01, best bound 2.200000000000e+01, gap 4.3478%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.15804600715637207
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 5644 rows, 4241 columns and 36766 nonzeros
# Model fingerprint: 0x6d77d84c
# Model has 224 simple general constraints
#   224 ABS
# Variable types: 105 continuous, 3688 integer (3688 binary)
# Semi-Variable types: 0 continuous, 448 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3151 rows and 2381 columns
# Presolve time: 0.06s
# Presolved: 2493 rows, 1860 columns, 9418 nonzeros
# Variable types: 0 continuous, 1860 integer (1350 binary)
# Found heuristic solution: objective 70.0000000
#
# Root relaxation: objective 2.900000e+01, 170 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   29.00000    0    2   70.00000   29.00000  58.6%     -    0s
# H    0     0                      32.0000000   29.00000  9.38%     -    0s
#
# Explored 1 nodes (452 simplex iterations) in 0.10 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 32 70
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.200000000000e+01, best bound 2.900000000000e+01, gap 9.3750%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.13664984703063965
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 5644 rows, 4241 columns and 36766 nonzeros
# Model fingerprint: 0xc92d50db
# Model has 224 simple general constraints
#   224 ABS
# Variable types: 105 continuous, 3688 integer (3688 binary)
# Semi-Variable types: 0 continuous, 448 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3151 rows and 2381 columns
# Presolve time: 0.06s
# Presolved: 2493 rows, 1860 columns, 9418 nonzeros
# Variable types: 0 continuous, 1860 integer (1350 binary)
# Found heuristic solution: objective 43.0000000
#
# Root relaxation: objective 3.200000e+01, 306 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   32.00000    0   22   43.00000   32.00000  25.6%     -    0s
#      0     0   32.00000    0   17   43.00000   32.00000  25.6%     -    0s
# H    0     0                      41.0000000   32.00000  22.0%     -    0s
# H    0     0                      32.0000000   32.00000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 17
#   Gomory: 3
#   Clique: 1
#   MIR: 6
#   RLT: 6
#
# Explored 1 nodes (658 simplex iterations) in 0.12 seconds (0.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 32 41 43
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.200000000000e+01, best bound 3.200000000000e+01, gap 0.0000%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.13703608512878418
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 5644 rows, 4241 columns and 36766 nonzeros
# Model fingerprint: 0x422ac7d7
# Model has 224 simple general constraints
#   224 ABS
# Variable types: 105 continuous, 3688 integer (3688 binary)
# Semi-Variable types: 0 continuous, 448 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3151 rows and 2381 columns
# Presolve time: 0.06s
# Presolved: 2493 rows, 1860 columns, 9418 nonzeros
# Variable types: 0 continuous, 1860 integer (1350 binary)
# Found heuristic solution: objective 76.0000000
#
# Root relaxation: objective 4.400000e+01, 145 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   44.00000    0    6   76.00000   44.00000  42.1%     -    0s
# H    0     0                      58.0000000   44.00000  24.1%     -    0s
# H    0     0                      56.0000000   44.00000  21.4%     -    0s
# H    0     0                      46.0000000   44.00000  4.35%     -    0s
#
# Explored 1 nodes (340 simplex iterations) in 0.10 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 46 56 58 76
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.600000000000e+01, best bound 4.400000000000e+01, gap 4.3478%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.15344977378845215
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 6608 rows, 4929 columns and 40172 nonzeros
# Model fingerprint: 0x45060215
# Model has 239 simple general constraints
#   239 ABS
# Variable types: 75 continuous, 4376 integer (4376 binary)
# Semi-Variable types: 0 continuous, 478 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2726 rows and 2071 columns
# Presolve time: 0.10s
# Presolved: 3882 rows, 2858 columns, 14772 nonzeros
# Variable types: 0 continuous, 2858 integer (2157 binary)
# Found heuristic solution: objective 38.0000000
#
# Root relaxation: objective 2.100000e+01, 291 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   21.00000    0    2   38.00000   21.00000  44.7%     -    0s
# H    0     0                      23.0000000   21.00000  8.70%     -    0s
#
# Explored 1 nodes (535 simplex iterations) in 0.15 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 23 38
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.300000000000e+01, best bound 2.100000000000e+01, gap 8.6957%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.15472793579101562
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 6608 rows, 4929 columns and 40172 nonzeros
# Model fingerprint: 0x81437217
# Model has 239 simple general constraints
#   239 ABS
# Variable types: 75 continuous, 4376 integer (4376 binary)
# Semi-Variable types: 0 continuous, 478 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2726 rows and 2071 columns
# Presolve time: 0.08s
# Presolved: 3882 rows, 2858 columns, 14772 nonzeros
# Variable types: 0 continuous, 2858 integer (2157 binary)
# Found heuristic solution: objective 247.0000000
# Found heuristic solution: objective 70.0000000
#
# Root relaxation: objective 2.900000e+01, 318 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   29.00000    0    2   70.00000   29.00000  58.6%     -    0s
# H    0     0                      32.0000000   29.00000  9.38%     -    0s
#
# Explored 1 nodes (591 simplex iterations) in 0.14 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 32 70 247
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.200000000000e+01, best bound 2.900000000000e+01, gap 9.3750%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.17605090141296387
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 6608 rows, 4929 columns and 40172 nonzeros
# Model fingerprint: 0x65fa6e70
# Model has 239 simple general constraints
#   239 ABS
# Variable types: 75 continuous, 4376 integer (4376 binary)
# Semi-Variable types: 0 continuous, 478 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2726 rows and 2071 columns
# Presolve time: 0.08s
# Presolved: 3882 rows, 2858 columns, 14772 nonzeros
# Variable types: 0 continuous, 2858 integer (2157 binary)
# Found heuristic solution: objective 124.0000000
# Found heuristic solution: objective 45.0000000
#
# Root relaxation: objective 3.200000e+01, 395 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   32.00000    0   27   45.00000   32.00000  28.9%     -    0s
# H    0     0                      40.0000000   32.00000  20.0%     -    0s
# H    0     0                      38.0000000   32.00000  15.8%     -    0s
#      0     0   32.00000    0   33   38.00000   32.00000  15.8%     -    0s
#      0     0   32.00000    0   29   38.00000   32.00000  15.8%     -    0s
#      0     0   32.00000    0  143   38.00000   32.00000  15.8%     -    0s
# H    0     0                      35.0000000   32.00000  8.57%     -    0s
#
# Explored 1 nodes (956 simplex iterations) in 0.20 seconds (0.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 35 37 38 ... 124
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.500000000000e+01, best bound 3.200000000000e+01, gap 8.5714%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.15862393379211426
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 6608 rows, 4929 columns and 40172 nonzeros
# Model fingerprint: 0xee043cee
# Model has 239 simple general constraints
#   239 ABS
# Variable types: 75 continuous, 4376 integer (4376 binary)
# Semi-Variable types: 0 continuous, 478 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2726 rows and 2071 columns
# Presolve time: 0.11s
# Presolved: 3882 rows, 2858 columns, 14772 nonzeros
# Variable types: 0 continuous, 2858 integer (2157 binary)
# Found heuristic solution: objective 76.0000000
#
# Root relaxation: objective 4.200000e+01, 291 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   42.00000    0    2   76.00000   42.00000  44.7%     -    0s
# H    0     0                      46.0000000   42.00000  8.70%     -    0s
#
# Explored 1 nodes (535 simplex iterations) in 0.16 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 46 76
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.600000000000e+01, best bound 4.200000000000e+01, gap 8.6957%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.4163849353790283
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 7434 rows, 5479 columns and 42548 nonzeros
# Model fingerprint: 0x8d2795e2
# Model has 243 simple general constraints
#   243 ABS
# Variable types: 67 continuous, 4926 integer (4926 binary)
# Semi-Variable types: 0 continuous, 486 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2724 rows and 2093 columns
# Presolve time: 0.09s
# Presolved: 4710 rows, 3386 columns, 17991 nonzeros
# Variable types: 0 continuous, 3386 integer (2631 binary)
# Found heuristic solution: objective 134.0000000
#
# Root relaxation: objective 2.100000e+01, 300 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   21.00000    0    4  134.00000   21.00000  84.3%     -    0s
# H    0     0                      97.0000000   21.00000  78.4%     -    0s
# H    0     0                      67.0000000   21.00000  68.7%     -    0s
# H    0     0                      64.0000000   21.00000  67.2%     -    0s
#      0     0   21.00000    0    9   64.00000   21.00000  67.2%     -    0s
# H    0     0                      38.0000000   21.00000  44.7%     -    0s
# H    0     0                      30.0000000   21.00000  30.0%     -    0s
# H    0     0                      26.0000000   21.00000  19.2%     -    0s
#      0     0   21.00000    0   54   26.00000   21.00000  19.2%     -    0s
#      0     0   21.00000    0    5   26.00000   21.00000  19.2%     -    0s
# H    0     0                      25.0000000   21.00000  16.0%     -    0s
# H    0     0                      24.0000000   21.00000  12.5%     -    0s
#      0     0   21.00000    0    8   24.00000   21.00000  12.5%     -    0s
#      0     0 infeasible    0        24.00000   24.00000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 7
#   Gomory: 2
#   Cover: 2
#   Implied bound: 2
#   Clique: 3
#   Flow cover: 1
#   Zero half: 4
#   RLT: 1
#   Relax-and-lift: 13
#
# Explored 1 nodes (867 simplex iterations) in 0.26 seconds (0.29 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 24 25 26 ... 134
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.400000000000e+01, best bound 2.400000000000e+01, gap 0.0000%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.1787858009338379
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 7434 rows, 5479 columns and 42548 nonzeros
# Model fingerprint: 0x0192d01d
# Model has 243 simple general constraints
#   243 ABS
# Variable types: 67 continuous, 4926 integer (4926 binary)
# Semi-Variable types: 0 continuous, 486 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2724 rows and 2093 columns
# Presolve time: 0.09s
# Presolved: 4710 rows, 3386 columns, 17991 nonzeros
# Variable types: 0 continuous, 3386 integer (2631 binary)
# Found heuristic solution: objective 249.0000000
# Found heuristic solution: objective 62.0000000
#
# Root relaxation: objective 2.800000e+01, 302 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   28.00000    0    6   62.00000   28.00000  54.8%     -    0s
# H    0     0                      34.0000000   28.00000  17.6%     -    0s
#      0     0   28.00000    0   14   34.00000   28.00000  17.6%     -    0s
#      0     0   28.00000    0   80   34.00000   28.00000  17.6%     -    0s
#      0     0   30.50000    0   22   34.00000   30.50000  10.3%     -    0s
#
# Explored 1 nodes (708 simplex iterations) in 0.23 seconds (0.27 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 34 62 249
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.400000000000e+01, best bound 3.100000000000e+01, gap 8.8235%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.1803269386291504
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 7434 rows, 5479 columns and 42548 nonzeros
# Model fingerprint: 0xddc52dab
# Model has 243 simple general constraints
#   243 ABS
# Variable types: 67 continuous, 4926 integer (4926 binary)
# Semi-Variable types: 0 continuous, 486 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2724 rows and 2093 columns
# Presolve time: 0.12s
# Presolved: 4710 rows, 3386 columns, 17991 nonzeros
# Variable types: 0 continuous, 3386 integer (2631 binary)
# Found heuristic solution: objective 134.0000000
#
# Root relaxation: objective 2.900000e+01, 466 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   29.00000    0   35  134.00000   29.00000  78.4%     -    0s
# H    0     0                      93.0000000   29.00000  68.8%     -    0s
# H    0     0                      73.0000000   29.00000  60.3%     -    0s
# H    0     0                      61.0000000   29.00000  52.5%     -    0s
#      0     0   29.00000    0   50   61.00000   29.00000  52.5%     -    0s
# H    0     0                      56.0000000   29.00000  48.2%     -    0s
# H    0     0                      52.0000000   29.00000  44.2%     -    0s
#      0     0   29.00000    0   46   52.00000   29.00000  44.2%     -    0s
# H    0     0                      45.0000000   29.00000  35.6%     -    0s
#      0     0   29.00000    0  248   45.00000   29.00000  35.6%     -    0s
#      0     0   29.00000    0   57   45.00000   29.00000  35.6%     -    0s
#      0     0   29.00000    0   46   45.00000   29.00000  35.6%     -    0s
# H    0     0                      42.0000000   29.00000  31.0%     -    0s
#      0     0   29.00000    0   81   42.00000   29.00000  31.0%     -    0s
#      0     0   29.00000    0   19   42.00000   29.00000  31.0%     -    0s
# H    0     0                      37.0000000   29.00000  21.6%     -    0s
# H    0     0                      34.0000000   29.00000  14.7%     -    0s
#      0     0   29.00000    0   14   34.00000   29.00000  14.7%     -    0s
#      0     0   29.00000    0   25   34.00000   29.00000  14.7%     -    0s
#      0     0   29.00000    0   30   34.00000   29.00000  14.7%     -    0s
#      0     0   29.00000    0   25   34.00000   29.00000  14.7%     -    0s
#      0     0   29.00000    0   12   34.00000   29.00000  14.7%     -    0s
#      0     0   29.20000    0  150   34.00000   29.20000  14.1%     -    0s
#      0     0   29.20000    0  140   34.00000   29.20000  14.1%     -    0s
# H    0     0                      32.0000000   30.00000  6.25%     -    0s
#      0     0   30.00000    0   11   32.00000   30.00000  6.25%     -    0s
#
# Cutting planes:
#   Learned: 65
#   Gomory: 15
#   Lift-and-project: 10
#   Cover: 71
#   Implied bound: 71
#   Clique: 50
#   MIR: 38
#   Flow cover: 23
#   GUB cover: 25
#   Zero half: 16
#   RLT: 8
#   Relax-and-lift: 24
#
# Explored 1 nodes (3106 simplex iterations) in 0.41 seconds (0.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 32 34 37 ... 93
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.200000000000e+01, best bound 3.000000000000e+01, gap 6.2500%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.2002267837524414
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 7434 rows, 5479 columns and 42548 nonzeros
# Model fingerprint: 0x654d9684
# Model has 243 simple general constraints
#   243 ABS
# Variable types: 67 continuous, 4926 integer (4926 binary)
# Semi-Variable types: 0 continuous, 486 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2724 rows and 2093 columns
# Presolve time: 0.09s
# Presolved: 4710 rows, 3386 columns, 17991 nonzeros
# Variable types: 0 continuous, 3386 integer (2631 binary)
# Found heuristic solution: objective 268.0000000
#
# Root relaxation: objective 4.200000e+01, 300 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   42.00000    0    4  268.00000   42.00000  84.3%     -    0s
# H    0     0                     194.0000000   42.00000  78.4%     -    0s
# H    0     0                     134.0000000   42.00000  68.7%     -    0s
# H    0     0                     128.0000000   42.00000  67.2%     -    0s
#      0     0   42.00000    0    9  128.00000   42.00000  67.2%     -    0s
# H    0     0                      76.0000000   42.00000  44.7%     -    0s
# H    0     0                      60.0000000   42.00000  30.0%     -    0s
# H    0     0                      52.0000000   42.00000  19.2%     -    0s
#      0     0   42.00000    0   54   52.00000   42.00000  19.2%     -    0s
#      0     0   42.00000    0    5   52.00000   42.00000  19.2%     -    0s
# H    0     0                      50.0000000   42.00000  16.0%     -    0s
# H    0     0                      48.0000000   42.00000  12.5%     -    0s
#      0     0   42.00000    0    8   48.00000   42.00000  12.5%     -    0s
#      0     0 infeasible    0        48.00000   48.00000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 7
#   Gomory: 2
#   Cover: 2
#   Implied bound: 2
#   Clique: 3
#   Flow cover: 1
#   Zero half: 4
#   RLT: 1
#   Relax-and-lift: 13
#
# Explored 1 nodes (867 simplex iterations) in 0.26 seconds (0.29 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 48 50 52 ... 268
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.800000000000e+01, best bound 4.800000000000e+01, gap 0.0000%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.18423128128051758
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 8236 rows, 6005 columns and 44740 nonzeros
# Model fingerprint: 0x09b74708
# Model has 245 simple general constraints
#   245 ABS
# Variable types: 63 continuous, 5452 integer (5452 binary)
# Semi-Variable types: 0 continuous, 490 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2829 rows and 2102 columns
# Presolve time: 0.10s
# Presolved: 5407 rows, 3903 columns, 21001 nonzeros
# Variable types: 0 continuous, 3903 integer (3049 binary)
#
# Root relaxation: objective 2.000000e+01, 364 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   20.00000    0    6          -   20.00000      -     -    0s
# H    0     0                      27.0000000   20.00000  25.9%     -    0s
# H    0     0                      26.0000000   20.00000  23.1%     -    0s
# H    0     0                      25.0000000   20.00000  20.0%     -    0s
#      0     0   20.00000    0    6   25.00000   20.00000  20.0%     -    0s
#      0     0   20.00000    0   12   25.00000   20.00000  20.0%     -    0s
#      0     0   20.00000    0   10   25.00000   20.00000  20.0%     -    0s
# H    0     0                      22.0000000   20.00000  9.09%     -    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 13
#   Implied bound: 3
#   Clique: 5
#   MIR: 12
#   Flow cover: 12
#   GUB cover: 1
#   Zero half: 5
#   RLT: 4
#   Relax-and-lift: 4
#
# Explored 1 nodes (740 simplex iterations) in 0.26 seconds (0.31 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 22 25 26 27
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.200000000000e+01, best bound 2.000000000000e+01, gap 9.0909%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.21059274673461914
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 8236 rows, 6005 columns and 44740 nonzeros
# Model fingerprint: 0xaf53c8f8
# Model has 245 simple general constraints
#   245 ABS
# Variable types: 63 continuous, 5452 integer (5452 binary)
# Semi-Variable types: 0 continuous, 490 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2829 rows and 2102 columns
# Presolve time: 0.10s
# Presolved: 5407 rows, 3903 columns, 21001 nonzeros
# Variable types: 0 continuous, 3903 integer (3049 binary)
#
# Root relaxation: objective 2.500000e+01, 369 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   25.00000    0   12          -   25.00000      -     -    0s
#      0     0   25.00000    0   21          -   25.00000      -     -    0s
# H    0     0                      36.0000000   25.00000  30.6%     -    0s
#      0     0   25.00000    0   87   36.00000   25.00000  30.6%     -    0s
#      0     0   25.00000    0   12   36.00000   25.00000  30.6%     -    0s
#      0     0   25.00000    0   34   36.00000   25.00000  30.6%     -    0s
# H    0     0                      35.0000000   25.00000  28.6%     -    0s
#      0     0   25.00000    0   21   35.00000   25.00000  28.6%     -    0s
# H    0     0                      34.0000000   25.00000  26.5%     -    0s
#      0     0   25.00000    0   31   34.00000   25.00000  26.5%     -    0s
#      0     0   25.00000    0   45   34.00000   25.00000  26.5%     -    0s
#      0     0   26.00000    0   53   34.00000   26.00000  23.5%     -    0s
#      0     0   27.50000    0   76   34.00000   27.50000  19.1%     -    0s
#      0     0   27.50000    0   79   34.00000   27.50000  19.1%     -    0s
# H    0     0                      32.0000000   28.00000  12.5%     -    0s
#      0     0   28.00000    0   73   32.00000   28.00000  12.5%     -    0s
#      0     0          -    0        32.00000   29.00000  9.38%     -    0s
#
# Cutting planes:
#   Learned: 24
#   Gomory: 9
#   Lift-and-project: 2
#   Cover: 40
#   Implied bound: 18
#   Clique: 51
#   MIR: 32
#   StrongCG: 1
#   Flow cover: 11
#   GUB cover: 6
#   Zero half: 7
#   Mod-K: 5
#   Relax-and-lift: 10
#
# Explored 1 nodes (2311 simplex iterations) in 0.40 seconds (0.42 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 32 34 35 36
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.200000000000e+01, best bound 2.900000000000e+01, gap 9.3750%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.19625496864318848
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 8236 rows, 6005 columns and 44740 nonzeros
# Model fingerprint: 0x8f2b9197
# Model has 245 simple general constraints
#   245 ABS
# Variable types: 63 continuous, 5452 integer (5452 binary)
# Semi-Variable types: 0 continuous, 490 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2829 rows and 2102 columns
# Presolve time: 0.11s
# Presolved: 5407 rows, 3903 columns, 21001 nonzeros
# Variable types: 0 continuous, 3903 integer (3049 binary)
#
# Root relaxation: objective 2.700000e+01, 533 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   27.00000    0   28          -   27.00000      -     -    0s
# H    0     0                      40.0000000   27.00000  32.5%     -    0s
#      0     0   27.00000    0   45   40.00000   27.00000  32.5%     -    0s
#      0     0   27.00000    0   43   40.00000   27.00000  32.5%     -    0s
#      0     0   27.00000    0  227   40.00000   27.00000  32.5%     -    0s
#      0     0   27.00000    0   36   40.00000   27.00000  32.5%     -    0s
#      0     0   27.00000    0   33   40.00000   27.00000  32.5%     -    0s
#      0     0   27.00000    0   67   40.00000   27.00000  32.5%     -    0s
# H    0     0                      37.0000000   27.00000  27.0%     -    0s
#      0     0   27.00000    0   10   37.00000   27.00000  27.0%     -    0s
#      0     0   27.00000    0   10   37.00000   27.00000  27.0%     -    0s
#      0     0   27.00000    0   11   37.00000   27.00000  27.0%     -    0s
# H    0     0                      36.0000000   27.00000  25.0%     -    0s
#      0     0   27.00000    0   26   36.00000   27.00000  25.0%     -    0s
#      0     0   27.00000    0   26   36.00000   27.00000  25.0%     -    0s
#      0     0   27.00000    0   26   36.00000   27.00000  25.0%     -    0s
#      0     0   27.00000    0   26   36.00000   27.00000  25.0%     -    0s
#      0     0   27.00000    0   32   36.00000   27.00000  25.0%     -    0s
#      0     0   27.00000    0   28   36.00000   27.00000  25.0%     -    0s
#      0     0   28.00000    0   21   36.00000   28.00000  22.2%     -    0s
#      0     0   28.00000    0   21   36.00000   28.00000  22.2%     -    0s
#      0     0   28.00000    0   35   36.00000   28.00000  22.2%     -    0s
# ...
# Best objective 2.900000000000e+01, best bound 2.700000000000e+01, gap 6.8966%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.24090290069580078
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 9960 rows, 7177 columns and 49774 nonzeros
# Model fingerprint: 0xfa00298e
# Model has 253 simple general constraints
#   253 ABS
# Variable types: 47 continuous, 6624 integer (6624 binary)
# Semi-Variable types: 0 continuous, 506 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 2785 rows and 1999 columns
# Presolve time: 0.14s
# Presolved: 7175 rows, 5178 columns, 28358 nonzeros
# Variable types: 0 continuous, 5178 integer (4187 binary)
# Found heuristic solution: objective 230.0000000
#
# Root relaxation: objective 3.800000e+01, 526 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   38.00000    0    8  230.00000   38.00000  83.5%     -    0s
# H    0     0                      44.0000000   38.00000  13.6%     -    0s
#      0     0   38.00000    0    9   44.00000   38.00000  13.6%     -    0s
#      0     0   38.00000    0   11   44.00000   38.00000  13.6%     -    0s
#      0     0   38.00000    0   11   44.00000   38.00000  13.6%     -    0s
#      0     0   38.00000    0    9   44.00000   38.00000  13.6%     -    0s
#      0     0   38.00000    0   10   44.00000   38.00000  13.6%     -    0s
#      0     0   38.00000    0   10   44.00000   38.00000  13.6%     -    0s
#      0     0   38.00000    0   10   44.00000   38.00000  13.6%     -    0s
#      0     0   38.00000    0   10   44.00000   38.00000  13.6%     -    0s
#      0     0   38.00000    0   10   44.00000   38.00000  13.6%     -    0s
#      0     0 infeasible    0        44.00000   44.00000  0.00%     -    0s
#
# Cutting planes:
#   Clique: 6
#   Zero half: 3
#   RLT: 6
#   Relax-and-lift: 6
#
# Explored 1 nodes (953 simplex iterations) in 0.29 seconds (0.40 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 44 230
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.400000000000e+01, best bound 4.400000000000e+01, gap 0.0000%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.2333672046661377
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 10872 rows, 7813 columns and 52538 nonzeros
# Model fingerprint: 0xa5e00e4d
# Model has 258 simple general constraints
#   258 ABS
# Variable types: 37 continuous, 7260 integer (7260 binary)
# Semi-Variable types: 0 continuous, 516 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3339 rows and 2298 columns
# Presolve time: 0.13s
# Presolved: 7533 rows, 5515 columns, 30057 nonzeros
# Variable types: 0 continuous, 5515 integer (4523 binary)
# Found heuristic solution: objective 87.0000000
#
# Root relaxation: objective 1.800000e+01, 562 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.00000    0    8   87.00000   18.00000  79.3%     -    0s
# H    0     0                      81.0000000   18.00000  77.8%     -    0s
# H    0     0                      44.0000000   18.00000  59.1%     -    0s
# H    0     0                      37.0000000   18.00000  51.4%     -    0s
#      0     0   18.00000    0    8   37.00000   18.00000  51.4%     -    0s
# H    0     0                      25.0000000   18.00000  28.0%     -    0s
# H    0     0                      22.0000000   18.00000  18.2%     -    0s
#      0     0   18.00000    0   13   22.00000   18.00000  18.2%     -    0s
#      0     0   18.00000    0    6   22.00000   18.00000  18.2%     -    0s
# H    0     0                      21.0000000   18.00000  14.3%     -    0s
# H    0     0                      20.0000000   18.00000  10.0%     -    0s
#      0     0   18.00000    0    6   20.00000   18.00000  10.0%     -    0s
#      0     0 infeasible    0        20.00000   20.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 4
#   Clique: 5
#   Zero half: 1
#   RLT: 1
#
# Explored 1 nodes (1290 simplex iterations) in 0.34 seconds (0.43 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 20 21 22 ... 87
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.23757314682006836
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 10872 rows, 7813 columns and 52538 nonzeros
# Model fingerprint: 0x28e5a872
# Model has 258 simple general constraints
#   258 ABS
# Variable types: 37 continuous, 7260 integer (7260 binary)
# Semi-Variable types: 0 continuous, 516 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3339 rows and 2298 columns
# Presolve time: 0.13s
# Presolved: 7533 rows, 5515 columns, 30057 nonzeros
# Variable types: 0 continuous, 5515 integer (4523 binary)
# Found heuristic solution: objective 268.0000000
#
# Root relaxation: objective 2.100000e+01, 427 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   21.00000    0   32  268.00000   21.00000  92.2%     -    0s
# H    0     0                      54.0000000   21.00000  61.1%     -    0s
# H    0     0                      52.0000000   21.00000  59.6%     -    0s
#      0     0   21.00000    0   46   52.00000   21.00000  59.6%     -    0s
# H    0     0                      43.0000000   21.00000  51.2%     -    0s
#      0     0   21.00000    0  146   43.00000   21.00000  51.2%     -    0s
#      0     0   21.00000    0   33   43.00000   21.00000  51.2%     -    0s
#      0     0   21.00000    0   64   43.00000   21.00000  51.2%     -    0s
#      0     0   21.00000    0   64   43.00000   21.00000  51.2%     -    0s
#      0     0   21.00000    0   46   43.00000   21.00000  51.2%     -    0s
#      0     0   21.00000    0   50   43.00000   21.00000  51.2%     -    0s
#      0     0   21.00000    0   50   43.00000   21.00000  51.2%     -    0s
#      0     0   21.00000    0   64   43.00000   21.00000  51.2%     -    0s
#      0     0   21.00000    0   65   43.00000   21.00000  51.2%     -    0s
# H    0     0                      41.0000000   21.00000  48.8%     -    0s
#      0     0   21.00000    0   65   41.00000   21.00000  48.8%     -    0s
#      0     2   21.00000    0   65   41.00000   21.00000  48.8%     -    0s
# H  437   382                      40.0000000   21.00000  47.5%   8.4    0s
# H  703   508                      37.0000000   21.00000  43.2%  10.6    0s
# H  857   574                      36.0000000   21.00000  41.7%  10.1    0s
# H  916   489                      34.0000000   21.00000  38.2%  10.2    0s
# H  938   463                      32.0000000   21.00000  34.4%  10.1    0s
# H 1996   915                      31.0000000   23.00000  25.8%  12.1    1s
# H 2139   881                      29.0000000   23.00000  20.7%  14.0    1s
#
# Cutting planes:
#   Gomory: 9
#   Lift-and-project: 1
#   Cover: 3
#   Implied bound: 10
#   Clique: 24
#   MIR: 2
#   GUB cover: 3
#   Zero half: 2
#   Relax-and-lift: 8
#
# Explored 2572 nodes (40244 simplex iterations) in 1.76 seconds (1.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 29 31 32 ... 52
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.900000000000e+01, best bound 2.900000000000e+01, gap 0.0000%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.24362921714782715
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 10872 rows, 7813 columns and 52538 nonzeros
# Model fingerprint: 0x6e12adcc
# Model has 258 simple general constraints
#   258 ABS
# Variable types: 37 continuous, 7260 integer (7260 binary)
# Semi-Variable types: 0 continuous, 516 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3339 rows and 2298 columns
# Presolve time: 0.16s
# Presolved: 7533 rows, 5515 columns, 30057 nonzeros
# Variable types: 0 continuous, 5515 integer (4523 binary)
# Found heuristic solution: objective 64.0000000
#
# Root relaxation: objective 2.200000e+01, 561 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   22.00000    0    8   64.00000   22.00000  65.6%     -    0s
# H    0     0                      56.0000000   22.00000  60.7%     -    0s
# H    0     0                      33.0000000   22.00000  33.3%     -    0s
#      0     0   22.00000    0   17   33.00000   22.00000  33.3%     -    0s
# H    0     0                      31.0000000   22.00000  29.0%     -    0s
#      0     0   22.00000    0   60   31.00000   22.00000  29.0%     -    0s
#      0     0   22.00000    0   28   31.00000   22.00000  29.0%     -    0s
#      0     0   22.00000    0    9   31.00000   22.00000  29.0%     -    0s
#      0     0   22.00000    0    9   31.00000   22.00000  29.0%     -    0s
#      0     0   22.00000    0   11   31.00000   22.00000  29.0%     -    0s
#      0     0   22.00000    0   11   31.00000   22.00000  29.0%     -    0s
#      0     0   22.00000    0   11   31.00000   22.00000  29.0%     -    0s
#      0     0   22.00000    0    9   31.00000   22.00000  29.0%     -    0s
#      0     0   22.00000    0    9   31.00000   22.00000  29.0%     -    0s
#      0     0   22.00000    0    9   31.00000   22.00000  29.0%     -    0s
#      0     2   22.00000    0    9   31.00000   22.00000  29.0%     -    0s
# H   72    82                      30.0000000   22.00000  26.7%   7.3    0s
# H  106    99                      29.0000000   22.00000  24.1%   6.6    0s
# H  142   124                      28.0000000   22.00000  21.4%   6.7    0s
# H  157   124                      26.0000000   22.00000  15.4%   6.4    0s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 6
#   Cover: 66
#   Implied bound: 27
#   Clique: 25
#   MIR: 15
#   Flow cover: 1
#   GUB cover: 14
#   Inf proof: 1
#   Zero half: 18
#   Relax-and-lift: 24
#
# Explored 568 nodes (5809 simplex iterations) in 0.76 seconds (0.81 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 26 28 29 ... 64
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.600000000000e+01, best bound 2.400000000000e+01, gap 7.6923%
# created all pairs
# connectomes/collapsed_prohibited_edges.txt
# Read prohibited edges: 59 prohibited edges
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2598042
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Setup time: 0.26103711128234863
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  0.1
#
# Academic license 2598042 - for non-commercial use only - registered to ah___@gradcenter.cuny.edu
# Optimize a model with 10872 rows, 7813 columns and 52538 nonzeros
# Model fingerprint: 0x672ee3db
# Model has 258 simple general constraints
#   258 ABS
# Variable types: 37 continuous, 7260 integer (7260 binary)
# Semi-Variable types: 0 continuous, 516 integer
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 3339 rows and 2298 columns
# Presolve time: 0.13s
# Presolved: 7533 rows, 5515 columns, 30057 nonzeros
# Variable types: 0 continuous, 5515 integer (4523 binary)
# Found heuristic solution: objective 174.0000000
#
# Root relaxation: objective 3.600000e+01, 562 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   36.00000    0    8  174.00000   36.00000  79.3%     -    0s
# H    0     0                     162.0000000   36.00000  77.8%     -    0s
# H    0     0                      88.0000000   36.00000  59.1%     -    0s
# H    0     0                      74.0000000   36.00000  51.4%     -    0s
#      0     0   36.00000    0    8   74.00000   36.00000  51.4%     -    0s
# H    0     0                      50.0000000   36.00000  28.0%     -    0s
# H    0     0                      44.0000000   36.00000  18.2%     -    0s
#      0     0   36.00000    0   13   44.00000   36.00000  18.2%     -    0s
#      0     0   36.00000    0    6   44.00000   36.00000  18.2%     -    0s
# H    0     0                      42.0000000   36.00000  14.3%     -    0s
# H    0     0                      40.0000000   36.00000  10.0%     -    0s
#      0     0   36.00000    0    6   40.00000   36.00000  10.0%     -    0s
#      0     0 infeasible    0        40.00000   40.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 4
#   Clique: 5
#   Zero half: 1
#   RLT: 1
#
# Explored 1 nodes (1290 simplex iterations) in 0.36 seconds (0.43 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 40 42 44 ... 174
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.000000000000e+01, best bound 4.000000000000e+01, gap 0.0000%

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# plt.rcParams.update({'font.size': 15})

# # Plotting
# fig, ax1 = plt.subplots(figsize=(8,5))

# # Plot the first numbers
# ax1.set_xlabel('Number of Clusters')
# ax1.set_ylabel('Modification')
# ax1.tick_params(axis='y')

# # Create a second y-axis
# ax2 = ax1.twinx()
# ax2.set_ylabel('P-Value')

# ax2.tick_params(axis='y')
# ax2.axhline(y=0.05, color='grey', linestyle='--')


# df = pd.read_csv('res_cons_collapsed.csv')
# df = pd.DataFrame(df.values.T)

# # Combine the first two rows into the headers
# new_columns = [
#     f"{df.iloc[0, col]}{df.iloc[1, col]}"
#     for col in range(df.shape[1])
# ]

# # Assign the new column headers
# df.columns = new_columns

# # Drop the first two rows and reset the index starting from 3
# df = df.iloc[2:].reset_index(drop=True)
# df.index += 3
# df = df.map(lambda x: eval(x) if isinstance(x, str) and x.startswith('(') and x.endswith(')') else x)

# # Find the tuple with the lowest second number in each row
# min_values = df.map(lambda x: x if isinstance(x, tuple) else None).apply(
#     lambda row: min(row, key=lambda x: x[1] if x else float('inf')), axis=1
# )

# # Extract the first and second numbers from the tuples
# first_numbers = min_values.map(lambda x: x[0])
# second_numbers = min_values.map(lambda x: x[1])

# ax2.plot(second_numbers.index, second_numbers, '--o', label='Collapsed P-Val', color='tab:blue')
# ax1.plot(first_numbers.index, first_numbers, '-o', label='Collapsed Repair', color='tab:blue')


# df = pd.read_csv('res_cons_uncollapsed.csv')
# df = pd.DataFrame(df.values.T)

# # Combine the first two rows into the headers
# new_columns = [
#     f"{df.iloc[0, col]}{df.iloc[1, col]}"
#     for col in range(df.shape[1])
# ]

# # Assign the new column headers
# df.columns = new_columns

# # Drop the first two rows and reset the index starting from 3
# df = df.iloc[2:].reset_index(drop=True)
# df.index += 3
# df = df.map(lambda x: eval(x) if isinstance(x, str) and x.startswith('(') and x.endswith(')') else x)

# # Find the tuple with the lowest second number in each row
# min_values = df.map(lambda x: x if isinstance(x, tuple) else None).apply(
#     lambda row: min(row, key=lambda x: x[1] if x else float('inf')), axis=1
# )

# # Extract the first and second numbers from the tuples
# first_numbers = min_values.map(lambda x: x[0])
# second_numbers = min_values.map(lambda x: x[1])

# ax2.plot(second_numbers.index, second_numbers, '--o', label='Uncollapsed P-Val', color='tab:red')
# ax1.plot(first_numbers.index, first_numbers, '-o', label='Uncollapsed Repair', color='tab:red')

# ax1.set_ylim([0.1, 0.25])
# ax2.set_ylim([0,0.16])

# fig.tight_layout()  # Adjust layout to prevent overlap
# plt.grid('on')
# fig.legend()
# plt.show()

# %% [markdown]
# ## Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

plt.rcParams.update({'font.size': 13})

# Plotting
fig, ax1 = plt.subplots(figsize=(8,5))

# Plot the first numbers
ax1.set_xlabel('Number of Clusters')
ax1.set_ylabel('Repair Percentage')
ax1.tick_params(axis='y')

# Create a second y-axis
ax2 = ax1.twinx()
ax2.set_ylabel('P-Value')

ax2.tick_params(axis='y')
ax2.axhline(y=0.05, color='grey', linestyle='--')


df = pd.read_csv('res_cons_prohibit_collapsed.csv')
df = pd.DataFrame(df.values.T)

# Combine the first two rows into the headers
new_columns = [
    f"{df.iloc[0, col]}{df.iloc[1, col]}"
    for col in range(df.shape[1])
]

# Assign the new column headers
df.columns = new_columns

# Drop the first two rows and reset the index starting from 3
df = df.iloc[2:].reset_index(drop=True)
df.index += 3
df = df.map(lambda x: eval(x) if isinstance(x, str) and x.startswith('(') and x.endswith(')') else x)

repairs = []
pvals = []
n_colors = []

for row in df.iterrows():
    n_colors.append(int(row[0]))
    best_repair = 1e100
    best_pval = 1.0
    
    for tup in row[1].values:
        if best_pval < 0.05 and tup[1] < 0.05 and tup[0] < best_repair: # already found a significant result, looking for better repair
            best_repair = tup[0]
            best_pval = tup[1]
        elif tup[1] < best_pval: # not found a significant result yet
            best_pval = tup[1]
            best_repair = tup[0]
    
    repairs.append(best_repair*100.0)
    pvals.append(best_pval)
    
ax2.plot(n_colors, pvals, '--o', label='Collapsed P-Value', color='tab:red')
ax1.plot(n_colors, repairs, '-o', label='Collapsed Repair %', color='tab:red')


##############################

df = pd.read_csv('res_cons_prohibit_uncollapsed.csv')
df = df[[x for idx, x in enumerate(df.columns) if 'un' in x or idx < 2]]
df = pd.DataFrame(df.values.T)

# Combine the first two rows into the headers
new_columns = [
    f"{df.iloc[0, col]}{df.iloc[1, col]}"
    for col in range(df.shape[1])
]

# Assign the new column headers
df.columns = new_columns

# Drop the first two rows and reset the index starting from 3
df = df.iloc[2:].reset_index(drop=True)
df.index += 3
df = df.map(lambda x: eval(x) if isinstance(x, str) and x.startswith('(') and x.endswith(')') else x)

repairs = []
pvals = []
n_colors = []

for row in df.iterrows():
    n_colors.append(int(row[0]))
    best_repair = 1e100
    best_pval = 1.0
    
    for tup in row[1].values:
        if best_pval < 0.05 and tup[1] < 0.05 and tup[0] < best_repair: # already found a significant result, looking for better repair
            best_repair = tup[0]
            best_pval = tup[1]
        elif tup[1] < best_pval: # not found a significant result yet
            best_pval = tup[1]
            best_repair = tup[0]
    
    repairs.append(best_repair*100.0)
    pvals.append(best_pval)
    
    
ax2.plot(n_colors, pvals, '--o', label='Uncollapsed P-Value', color='tab:blue')
ax1.plot(n_colors, repairs, '-o', label='Uncollapsed Repair %', color='tab:blue')

ax1.set_xticks([3,4,5,6,7,8,9,10,11], [4,5,6,7,8,9,10,11,12])

ax1.set_ylim([5, 20])
ax2.set_ylim([0,0.4])

rect = Rectangle((5.75, 5.15), 0.5, 9.75, 
                 linewidth=2, edgecolor='black', linestyle="--", facecolor='none', alpha=0.5)
ax1.add_patch(rect)


fig.tight_layout()  # Adjust layout to prevent overlap
fig.legend(loc='upper right', bbox_to_anchor=(0.885,0.95))
ax1.grid('on','major','y')
fig.savefig('plots/percentages_and_pvalues.png', dpi=400)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/48/6kt_2mjx06n4cx1rc74n8lpr0000gn/T/ipykernel_65581/2031167874.py in ?()
#      34
#      35 # Drop the first two rows and reset the index starting from 3
#      36 df = df.iloc[2:].reset_index(drop=True)
#      37 df.index += 3
# ---> 38 df = df.map(lambda x: eval(x) if isinstance(x, str) and x.startswith('(') and x.endswith(')') else x)
#      39
#      40 repairs = []
#      41 pvals = []
#
# ~/opt/miniconda3/envs/NYU-DL/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
orig = pd.read_csv('connectomes/collapsed_varshney.graph.txt', sep='\t', header=None)
prohib = pd.read_csv('connectomes/collapsed_prohibited_edges.txt', sep='\t', header=None)

# %%
neurons = ['DA02', 'VA02', 'VA03', 'DA03', 'DA01', 'DA08', 'DA09', 'VA12', 'VA07', 'VA05', 'VA04', 'VA06', 'DA07', 'VA01', 'VA09', 'VA10', 'VA11', 'DA05', 'DA04', 'VA08', 'DA06', 'AVA', 'AVD', 'AVE']
mapping_neuron_to_idx = {neurons[idx]:idx for idx in range(len(neurons))}

# %%
import numpy as np

orig_m = np.zeros((len(neurons), len(neurons)))
prohib_m = np.zeros((len(neurons), len(neurons)))

for row in orig.iterrows():
    orig_m[mapping_neuron_to_idx[row[1][0]]][mapping_neuron_to_idx[row[1][1]]] = 1
    
for row in prohib.iterrows():
    prohib_m[mapping_neuron_to_idx[row[1][0]]][mapping_neuron_to_idx[row[1][1]]] = 1

# %%
plt.imshow(orig_m)
plt.xticks(range(len(neurons)), neurons, rotation=90)
plt.yticks(range(len(neurons)), neurons);

# %%
plt.imshow(prohib_m)
plt.xticks(range(len(neurons)), neurons, rotation=90)
plt.yticks(range(len(neurons)), neurons);
